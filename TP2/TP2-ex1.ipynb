# %% [markdown]
# # Trabalho Prático 2

# %% [markdown]
# ## Grupo 04 - Renato Garcia (A101987) & Bernardo Moniz (A102497)

# %% [markdown]
# ## Problema 1
# ### Enunciado
#
# 1. Considere a descrição da cifra A5/1 que consta no documento +Lógica Computacional: a Cifra A5/1. Informação complementar pode ser obtida no artigo da Wikipedia.
#
#    Pretende-se
#
#    a. Definir e codificar, em Z3 e usando o tipo BitVec para modelar a informação, uma FSM que descreva o gerador de chaves.
#
#    b. Considere as seguintes eventuais propriedades de erro:
#
#       i. ocorrência de um “burst” $\,\mathsf{0}^t\,$  ($t$ zeros) que ocorre em $\,2^t\,$ passos ou menos.
#
#       ii. ocorrência de um “burst” de tamanho $\,t\,$ que repete um “burst” anterior no mesmo output em $2^{t/2}$ passos ou menos.
#
#    Tente codificar estas propriedades e verificar se são acessíveis a partir de um estado inicial aleatoriamente gerado.

# %% [markdown]
# ### Resolução

# %% [markdown]
# KEY GENERATOR CIFRA A5/1
#
# Neste trabalho, foram seguidas as indicações presentes nos documentos apresentados pelos docentes, bem como alguma informação online.
#
# São feitas 64 + 22 + 100 iterações antes de ser gerada a keystream, tendo esta um valor fixo de 228 bits (este poderia ser alterado oferendo um valor k para ser gerada uma keystream com k bits).
#
# Por fim, verifica-se as propriedades de erro solicitadas.

# %%
from z3 import * 
import random

def declare(step):
    """Declara as variáveis de estado para um dado passo"""
    return (
        BitVec(f'R1_{step}', 19),
        BitVec(f'R2_{step}', 22),
        BitVec(f'R3_{step}', 23)
    )

def init():
    """Inicializa os registadores R1, R2, e R3 com valores aleatórios"""
    R1_0, R2_0, R3_0 = declare(0)
    
    # Valores iniciais aleatórios
    r1_init = random.getrandbits(19)
    r2_init = random.getrandbits(22)
    r3_init = random.getrandbits(23)
    
    solver = Solver()
    solver.add(R1_0 == r1_init, R2_0 == r2_init, R3_0 == r3_init)
    
    return solver, R1_0, R2_0, R3_0

def trans(solver, step, R1_curr, R2_curr, R3_curr, key_bit=None, fc_bit=None, majority_rule=False, generate_keystream=False):
    """Define as transições de estado para uma etapa"""
    R1_next, R2_next, R3_next = declare(step + 1)

    fb1 = Extract(0, 0, R1_curr) ^ Extract(1, 1, R1_curr) ^ Extract(2, 2, R1_curr) ^ Extract(5, 5, R1_curr)
    fb2 = Extract(0, 0, R2_curr) ^ Extract(1, 1, R2_curr)
    fb3 = Extract(0, 0, R3_curr) ^ Extract(1, 1, R3_curr) ^ Extract(2, 2, R3_curr) ^ Extract(15, 15, R3_curr)
    
    if key_bit is not None:
        solver.add(
            R1_next == Concat(fb1 ^ key_bit, Extract(18, 1, R1_curr)),
            R2_next == Concat(fb2 ^ key_bit, Extract(21, 1, R2_curr)),
            R3_next == Concat(fb3 ^ key_bit, Extract(22, 1, R3_curr))
        )
    elif fc_bit is not None:
        solver.add(
            R1_next == Concat(fb1 ^ fc_bit, Extract(18, 1, R1_curr)),
            R2_next == Concat(fb2 ^ fc_bit, Extract(21, 1, R2_curr)),
            R3_next == Concat(fb3 ^ fc_bit, Extract(22, 1, R3_curr))
        )
    elif majority_rule or generate_keystream:
        C1, C2, C3 = Extract(10, 10, R1_curr), Extract(11, 11, R2_curr), Extract(12, 12, R3_curr)
        count_ones = If(C1 == 1, 1, 0) + If(C2 == 1, 1, 0) + If(C3 == 1, 1, 0)
        maj = If(count_ones >= 2, BitVecVal(1, 1), BitVecVal(0, 1))

        if generate_keystream:
            # Bits de saída para a keystream
            output_bit = Extract(0, 0, R1_curr) ^ Extract(0, 0, R2_curr) ^ Extract(0, 0, R3_curr)
            keystream_bit = BitVec(f'keystream_{step}', 1)
            solver.add(keystream_bit == output_bit)

        solver.add(
            If(C1 == maj, R1_next == Concat(fb1, Extract(18, 1, R1_curr)), R1_next == R1_curr),
            If(C2 == maj, R2_next == Concat(fb2, Extract(21, 1, R2_curr)), R2_next == R2_curr),
            If(C3 == maj, R3_next == Concat(fb3, Extract(22, 1, R3_curr)), R3_next == R3_curr)
        )
    
    return R1_next, R2_next, R3_next

def get_keystream_bytes(keystream_bits):
    """Converte a string de bits em bytes"""
    keystream_clean = keystream_bits.replace(" ", "")
    bytes_list = []
    for i in range(0, len(keystream_clean), 8):
        byte = keystream_clean[i:i+8]
        if len(byte) == 8:
            bytes_list.append(int(byte, 2))
    return bytes_list

def print_state_with_keystream(model, step, bits_r1, bits_r2, bits_r3, keystream_bits="", print_keystream=False):
    """Função auxiliar para imprimir o estado dos registadores e keystream"""
    R1 = model[BitVec(f'R1_{step}', bits_r1)]
    R2 = model[BitVec(f'R2_{step}', bits_r2)]
    R3 = model[BitVec(f'R3_{step}', bits_r3)]
    
    print(f"\nEstado {step}:")
    print(f"R1: {format(R1.as_long(), f'0{bits_r1}b')}")
    print(f"R2: {format(R2.as_long(), f'0{bits_r2}b')}")
    print(f"R3: {format(R3.as_long(), f'0{bits_r3}b')}")
    
    if print_keystream:
        current_bit = model[BitVec(f'keystream_{step-1}', 1)].as_long()
        new_keystream = keystream_bits + str(current_bit)
        
        # Formatação da keystream em grupos de 8 bits
        formatted_keystream = ""
        for i in range(0, len(new_keystream), 8):
            formatted_keystream += new_keystream[i:i+8] + " "
            
        print("\nKeystream gerada até agora:")
        print(f"Em bits: {formatted_keystream.strip()}")
        
        # Mostra os bytes já completos
        bytes_list = get_keystream_bytes(new_keystream)
        if bytes_list:
            print(f"Em bytes (hex): {bytes(bytes_list).hex()}")
            print(f"Número de bytes gerados: {len(bytes_list)}")
        
        return new_keystream
    
    return keystream_bits
    
def verificar_burst_keystream(model, t, keystream_bits):
    """Verifica a ocorrência de um burst de t zeros na keystream até 2^t passos"""
    burst_size = 2 ** t
    burst_pattern = BitVecVal(0, t)  # Padrão de burst de t zeros
    max_steps = burst_size  # Limite máximo de passos a verificar

    solver_burst = Solver()

    print("\n=== Verificação de Burst na Keystream ===")
    print(f"Verificando bursts nos primeiros {max_steps} passos...")
    burst_detected = False

    # Limita a verificação a 2^t passos ou ao tamanho da keystream, o que for menor
    steps_to_check = min(max_steps, len(keystream_bits) - t + 1)

    for i in range(steps_to_check):
        slice_bits = BitVecVal(int(keystream_bits[i:i+t], 2), t)

        solver_burst.push()
        solver_burst.add(slice_bits == burst_pattern)

        if solver_burst.check() == sat:
            print(f"Burst de {t} zeros encontrado na posição {i} da keystream.")
            burst_detected = True
        solver_burst.pop()

    if not burst_detected:
        print(f"Nenhum burst detectado nos primeiros {steps_to_check} passos da keystream.")

def verificar_repeticao_burst_keystream(model, keystream_length, t):
    """Verifica a repetição de um burst de `t` zeros na keystream em até `2^(t/2)` passos ou menos."""
    repeat_interval = 2 ** (t // 2)
    burst_pattern = BitVecVal(0, t)  # Padrão de burst de `t` zeros
    repeticao_detectada = False

    print("\n=== Verificação de Repetição de Burst na Keystream ===")

    for step in range(keystream_length):
        for offset in range(1, repeat_interval + 1):
            next_step = step + offset
            if next_step >= keystream_length:
                break  # Limite de passos atingido

            # Verifica se ambos os passos têm um burst de `t` zeros
            keystream_slice_1 = 0
            keystream_slice_2 = 0
            
            for pos in range(t):
                if step + pos < keystream_length:
                    next_bit_1 = model[BitVec(f'keystream_{step + pos}', 1)]
                    if next_bit_1 == 0:
                        keystream_slice_1 += 1  # Incrementa a contagem se for zero

                if next_step + pos < keystream_length:
                    next_bit_2 = model[BitVec(f'keystream_{next_step + pos}', 1)]
                    if next_bit_2 == 0:
                        keystream_slice_2 += 1  # Incrementa a contagem se for zero

            if keystream_slice_1 == t and keystream_slice_2 == t:
                print(f"Repetição detectada na keystream entre os passos {step} e {next_step}.")
                repeticao_detectada = True
                break  # Sai do loop quando uma repetição é encontrada

    if not repeticao_detectada:
        print("Nenhuma repetição de burst detectada na keystream.")

# Atualizando a função gera_traço para chamar as novas funções de verificação
def gera_traço(keystream_length=228):
    """Executa a simulação completa do gerador da chave A5/1"""
    print("A iniciar simulação do gerador A5/1...")

    solver, R1, R2, R3 = init()
    current_step = 0
    session_key = BitVecVal(0b0100111000101111010011010111110000011110101110001000101100111010, 64)
    frame_counter = BitVecVal(0b1110101011001111001011, 22)
    
    # Combinações com a session_key (64 iterações)
    print("\nAdicionando restrições de combinações da session_key...")
    for i in range(64):
        key_bit = Extract(63 - i, 63 - i, session_key)
        R1, R2, R3 = trans(solver, current_step, R1, R2, R3, key_bit=key_bit)
        current_step += 1
    
    # Combinações com o frame counter (22 iterações)
    print("\nAdicionando restrições de combinações do frame counter...")
    for i in range(22):
        fc_bit = Extract(21 - i, 21 - i, frame_counter)
        R1, R2, R3 = trans(solver, current_step, R1, R2, R3, fc_bit=fc_bit)
        current_step += 1
    
    # Clocking pela regra da maioria (100 iterações)
    print("\nAdicionando restrições de clocking com regra da maioria...")
    for _ in range(100):
        R1, R2, R3 = trans(solver, current_step, R1, R2, R3, majority_rule=True)
        current_step += 1

    # Geração da keystream
    print("\nAdicionando restrições para a geração da keystream...")
    for _ in range(keystream_length):
        R1, R2, R3 = trans(solver, current_step, R1, R2, R3, generate_keystream=True)
        current_step += 1
    
    print("\nA verificar satisfiabilidade...")
    if solver.check() == sat:
        print("Caminho válido encontrado! A imprimir estados...")
        model = solver.model()

        # Sessão de mistura com chave de sessão
        print("\n=== Mistura com Chave de Sessão ===")
        for i in range(65):  # De 0 a 64
            print_state_with_keystream(model, i, 19, 22, 23)

        # Sessão de mistura com frame counter
        print("\n=== Mistura com Frame Counter ===")
        for i in range(65, 87):  # De 65 a 86 (22 iterações)
            print_state_with_keystream(model, i, 19, 22, 23)

        # Clocking pela regra da maioria
        print("\n=== Clocking pela Regra da Maioria ===")
        for i in range(87, 187):  # De 87 até 186 (100 iterações)
            print_state_with_keystream(model, i, 19, 22, 23)

        # Geração da keystream com visualização passo a passo
        print("\n=== Geração da Keystream ===")
        print("A iniciar geração de", keystream_length, "bits da keystream...")
        keystream = ""
        for i in range(187, current_step + 1):
            keystream = print_state_with_keystream(model, i, 19, 22, 23, keystream, print_keystream=True)

        
        verificar_burst_keystream(model, t=3, keystream_bits=keystream)
        verificar_repeticao_burst_keystream(model, keystream_length, t=6)  
    else:
        print("Nenhum caminho válido encontrado.")
        print("", solver.unsat_core())

gera_traço()
# Out:
# A iniciar simulação do gerador A5/1...
#
# Adicionando restrições de combinações da session_key...
#
# Adicionando restrições de combinações do frame counter...
#
# Adicionando restrições de clocking com regra da maioria...
#
# Adicionando restrições para a geração da keystream...
#
# A verificar satisfiabilidade...
# Caminho válido encontrado! A imprimir estados...
#
# === Mistura com Chave de Sessão ===
#
# Estado 0:
# R1: 1101111000111110001
# R2: 1010000110100010010110
# R3: 01011111101101000100000
#
# Estado 1:
# R1: 0110111100011111000
# R2: 1101000011010001001011
# R3: 10101111110110100010000
#
# Estado 2:
# R1: 0011011110001111100
# R2: 1110100001101000100101
# R3: 01010111111011010001000
#
# Estado 3:
# R1: 0001101111000111110
# R2: 1111010000110100010010
# R3: 10101011111101101000100
#
# Estado 4:
# R1: 1000110111100011111
# R2: 1111101000011010001001
# R3: 01010101111110110100010
#
# Estado 5:
# R1: 0100011011110001111
# R2: 0111110100001101000100
# R3: 10101010111111011010001
#
# Estado 6:
# R1: 0010001101111000111
# R2: 1011111010000110100010
# R3: 01010101011111101101000
#
# Estado 7:
# R1: 0001000110111100011
# R2: 0101111101000011010001
# R3: 00101010101111110110100
#
# Estado 8:
# R1: 1000100011011110001
# R2: 1010111110100001101000
# R3: 10010101010111111011010
#
# Estado 9:
# R1: 0100010001101111000
# R2: 0101011111010000110100
# R3: 01001010101011111101101
#
# Estado 10:
# R1: 1010001000110111100
# R2: 0010101111101000011010
# R3: 00100101010101111110110
#
# Estado 11:
# R1: 1101000100011011110
# R2: 0001010111110100001101
# R3: 00010010101010111111011
#
# Estado 12:
# R1: 0110100010001101111
# R2: 1000101011111010000110
# R3: 00001001010101011111101
#
# Estado 13:
# R1: 1011010001000110111
# R2: 0100010101111101000011
# R3: 00000100101010101111110
#
# Estado 14:
# R1: 1101101000100011011
# R2: 1010001010111110100001
# R3: 10000010010101010111111
#
# Estado 15:
# R1: 1110110100010001101
# R2: 0101000101011111010000
# R3: 01000001001010101011111
#
# Estado 16:
# R1: 1111011010001000110
# R2: 1010100010101111101000
# R3: 10100000100101010101111
#
# Estado 17:
# R1: 0111101101000100011
# R2: 0101010001010111110100
# R3: 11010000010010101010111
#
# Estado 18:
# R1: 0011110110100010001
# R2: 1010101000101011111010
# R3: 01101000001001010101011
#
# Estado 19:
# R1: 1001111011010001000
# R2: 1101010100010101111101
# R3: 00110100000100101010101
#
# Estado 20:
# R1: 0100111101101000100
# R2: 1110101010001010111110
# R3: 00011010000010010101010
#
# Estado 21:
# R1: 0010011110110100010
# R2: 0111010101000101011111
# R3: 00001101000001001010101
#
# Estado 22:
# R1: 1001001111011010001
# R2: 1011101010100010101111
# R3: 00000110100000100101010
#
# Estado 23:
# R1: 1100100111101101000
# R2: 0101110101010001010111
# R3: 10000011010000010010101
#
# Estado 24:
# R1: 0110010011110110100
# R2: 1010111010101000101011
# R3: 01000001101000001001010
#
# Estado 25:
# R1: 0011001001111011010
# R2: 0101011101010100010101
# R3: 00100000110100000100101
#
# Estado 26:
# R1: 0001100100111101101
# R2: 0010101110101010001010
# R3: 10010000011010000010010
#
# Estado 27:
# R1: 0000110010011110110
# R2: 0001010111010101000101
# R3: 01001000001101000001001
#
# Estado 28:
# R1: 0000011001001111011
# R2: 0000101011101010100010
# R3: 00100100000110100000100
#
# Estado 29:
# R1: 0000001100100111101
# R2: 0000010101110101010001
# R3: 00010010000011010000010
#
# Estado 30:
# R1: 0000000110010011110
# R2: 0000001010111010101000
# R3: 00001001000001101000001
#
# Estado 31:
# R1: 0000000011001001111
# R2: 0000000101011101010100
# R3: 00000100100000110100000
#
# Estado 32:
# R1: 1000000001100100111
# R2: 0000000010101110101010
# R3: 00000010010000011010000
#
# Estado 33:
# R1: 0100000000110010011
# R2: 1000000001010111010101
# R3: 00000001001000001101000
#
# Estado 34:
# R1: 0010000000011001001
# R2: 1100000000101011101010
# R3: 10000000100100000110100
#
# Estado 35:
# R1: 1001000000001100100
# R2: 1110000000010101110101
# R3: 11000000010010000011010
#
# Estado 36:
# R1: 1100100000000110010
# R2: 0111000000001010111010
# R3: 01100000001001000001101
#
# Estado 37:
# R1: 1110010000000011001
# R2: 0011100000000101011101
# R3: 10110000000100100000110
#
# Estado 38:
# R1: 0111001000000001100
# R2: 0001110000000010101110
# R3: 11011000000010010000011
#
# Estado 39:
# R1: 0011100100000000110
# R2: 0000111000000001010111
# R3: 11101100000001001000001
#
# Estado 40:
# R1: 0001110010000000011
# R2: 0000011100000000101011
# R3: 11110110000000100100000
#
# Estado 41:
# R1: 1000111001000000001
# R2: 1000001110000000010101
# R3: 11111011000000010010000
#
# Estado 42:
# R1: 1100011100100000000
# R2: 1100000111000000001010
# R3: 11111101100000001001000
#
# Estado 43:
# R1: 1110001110010000000
# R2: 0110000011100000000101
# R3: 01111110110000000100100
#
# Estado 44:
# R1: 1111000111001000000
# R2: 0011000001110000000010
# R3: 00111111011000000010010
#
# Estado 45:
# R1: 1111100011100100000
# R2: 0001100000111000000001
# R3: 10011111101100000001001
#
# Estado 46:
# R1: 1111110001110010000
# R2: 1000110000011100000000
# R3: 01001111110110000000100
#
# Estado 47:
# R1: 0111111000111001000
# R2: 0100011000001110000000
# R3: 00100111111011000000010
#
# Estado 48:
# R1: 0011111100011100100
# R2: 0010001100000111000000
# R3: 00010011111101100000001
#
# Estado 49:
# R1: 1001111110001110010
# R2: 1001000110000011100000
# R3: 10001001111110110000000
#
# Estado 50:
# R1: 0100111111000111001
# R2: 0100100011000001110000
# R3: 11000100111111011000000
#
# Estado 51:
# R1: 0010011111100011100
# R2: 0010010001100000111000
# R3: 01100010011111101100000
#
# Estado 52:
# R1: 1001001111110001110
# R2: 0001001000110000011100
# R3: 00110001001111110110000
#
# Estado 53:
# R1: 1100100111111000111
# R2: 1000100100011000001110
# R3: 00011000100111111011000
#
# Estado 54:
# R1: 1110010011111100011
# R2: 1100010010001100000111
# R3: 00001100010011111101100
#
# Estado 55:
# R1: 0111001001111110001
# R2: 1110001001000110000011
# R3: 00000110001001111110110
#
# Estado 56:
# R1: 1011100100111111000
# R2: 1111000100100011000001
# R3: 10000011000100111111011
#
# Estado 57:
# R1: 1101110010011111100
# R2: 1111100010010001100000
# R3: 11000001100010011111101
#
# Estado 58:
# R1: 0110111001001111110
# R2: 0111110001001000110000
# R3: 11100000110001001111110
#
# Estado 59:
# R1: 0011011100100111111
# R2: 1011111000100100011000
# R3: 11110000011000100111111
#
# Estado 60:
# R1: 1001101110010011111
# R2: 1101111100010010001100
# R3: 01111000001100010011111
#
# Estado 61:
# R1: 0100110111001001111
# R2: 1110111110001001000110
# R3: 00111100000110001001111
#
# Estado 62:
# R1: 1010011011100100111
# R2: 1111011111000100100011
# R3: 10011110000011000100111
#
# Estado 63:
# R1: 1101001101110010011
# R2: 1111101111100010010001
# R3: 01001111000001100010011
#
# Estado 64:
# R1: 0110100110111001001
# R2: 1111110111110001001000
# R3: 10100111100000110001001
#
# === Mistura com Frame Counter ===
#
# Estado 65:
# R1: 0011010011011100100
# R2: 1111111011111000100100
# R3: 11010011110000011000100
#
# Estado 66:
# R1: 1001101001101110010
# R2: 1111111101111100010010
# R3: 11101001111000001100010
#
# Estado 67:
# R1: 1100110100110111001
# R2: 0111111110111110001001
# R3: 11110100111100000110001
#
# Estado 68:
# R1: 0110011010011011100
# R2: 1011111111011111000100
# R3: 11111010011110000011000
#
# Estado 69:
# R1: 0011001101001101110
# R2: 1101111111101111100010
# R3: 11111101001111000001100
#
# Estado 70:
# R1: 1001100110100110111
# R2: 1110111111110111110001
# R3: 01111110100111100000110
#
# Estado 71:
# R1: 1100110011010011011
# R2: 0111011111111011111000
# R3: 10111111010011110000011
#
# Estado 72:
# R1: 0110011001101001101
# R2: 0011101111111101111100
# R3: 11011111101001111000001
#
# Estado 73:
# R1: 1011001100110100110
# R2: 1001110111111110111110
# R3: 11101111110100111100000
#
# Estado 74:
# R1: 0101100110011010011
# R2: 0100111011111111011111
# R3: 01110111111010011110000
#
# Estado 75:
# R1: 0010110011001101001
# R2: 0010011101111111101111
# R3: 10111011111101001111000
#
# Estado 76:
# R1: 0001011001100110100
# R2: 0001001110111111110111
# R3: 11011101111110100111100
#
# Estado 77:
# R1: 1000101100110011010
# R2: 1000100111011111111011
# R3: 11101110111111010011110
#
# Estado 78:
# R1: 0100010110011001101
# R2: 1100010011101111111101
# R3: 11110111011111101001111
#
# Estado 79:
# R1: 1010001011001100110
# R2: 0110001001110111111110
# R3: 11111011101111110100111
#
# Estado 80:
# R1: 0101000101100110011
# R2: 0011000100111011111111
# R3: 11111101110111111010011
#
# Estado 81:
# R1: 1010100010110011001
# R2: 0001100010011101111111
# R3: 11111110111011111101001
#
# Estado 82:
# R1: 1101010001011001100
# R2: 0000110001001110111111
# R3: 11111111011101111110100
#
# Estado 83:
# R1: 0110101000101100110
# R2: 1000011000100111011111
# R3: 11111111101110111111010
#
# Estado 84:
# R1: 1011010100010110011
# R2: 0100001100010011101111
# R3: 01111111110111011111101
#
# Estado 85:
# R1: 0101101010001011001
# R2: 1010000110001001110111
# R3: 00111111111011101111110
#
# Estado 86:
# R1: 0010110101000101100
# R2: 1101000011000100111011
# R3: 00011111111101110111111
#
# === Clocking pela Regra da Maioria ===
#
# Estado 87:
# R1: 0001011010100010110
# R2: 0110100001100010011101
# R3: 00011111111101110111111
#
# Estado 88:
# R1: 0000101101010001011
# R2: 1011010000110001001110
# R3: 00001111111110111011111
#
# Estado 89:
# R1: 0000101101010001011
# R2: 1101101000011000100111
# R3: 00000111111111011101111
#
# Estado 90:
# R1: 0000010110101000101
# R2: 0110110100001100010011
# R3: 00000111111111011101111
#
# Estado 91:
# R1: 0000001011010100010
# R2: 0110110100001100010011
# R3: 00000011111111101110111
#
# Estado 92:
# R1: 0000000101101010001
# R2: 0110110100001100010011
# R3: 00000001111111110111011
#
# Estado 93:
# R1: 1000000010110101000
# R2: 0011011010000110001001
# R3: 00000001111111110111011
#
# Estado 94:
# R1: 1100000001011010100
# R2: 0011011010000110001001
# R3: 10000000111111111011101
#
# Estado 95:
# R1: 1110000000101101010
# R2: 1001101101000011000100
# R3: 10000000111111111011101
#
# Estado 96:
# R1: 0111000000010110101
# R2: 0100110110100001100010
# R3: 10000000111111111011101
#
# Estado 97:
# R1: 0111000000010110101
# R2: 1010011011010000110001
# R3: 01000000011111111101110
#
# Estado 98:
# R1: 1011100000001011010
# R2: 1101001101101000011000
# R3: 01000000011111111101110
#
# Estado 99:
# R1: 1011100000001011010
# R2: 0110100110110100001100
# R3: 00100000001111111110111
#
# Estado 100:
# R1: 1011100000001011010
# R2: 0011010011011010000110
# R3: 10010000000111111111011
#
# Estado 101:
# R1: 1101110000000101101
# R2: 1001101001101101000011
# R3: 01001000000011111111101
#
# Estado 102:
# R1: 1110111000000010110
# R2: 1001101001101101000011
# R3: 00100100000001111111110
#
# Estado 103:
# R1: 0111011100000001011
# R2: 1001101001101101000011
# R3: 00010010000000111111111
#
# Estado 104:
# R1: 0011101110000000101
# R2: 1001101001101101000011
# R3: 10001001000000011111111
#
# Estado 105:
# R1: 0001110111000000010
# R2: 0100110100110110100001
# R3: 10001001000000011111111
#
# Estado 106:
# R1: 1000111011100000001
# R2: 1010011010011011010000
# R3: 10001001000000011111111
#
# Estado 107:
# R1: 1000111011100000001
# R2: 0101001101001101101000
# R3: 01000100100000001111111
#
# Estado 108:
# R1: 1000111011100000001
# R2: 0010100110100110110100
# R3: 10100010010000000111111
#
# Estado 109:
# R1: 1100011101110000000
# R2: 0001010011010011011010
# R3: 10100010010000000111111
#
# Estado 110:
# R1: 0110001110111000000
# R2: 1000101001101001101101
# R3: 11010001001000000011111
#
# Estado 111:
# R1: 0011000111011100000
# R2: 1100010100110100110110
# R3: 01101000100100000001111
#
# Estado 112:
# R1: 1001100011101110000
# R2: 1110001010011010011011
# R3: 01101000100100000001111
#
# Estado 113:
# R1: 1001100011101110000
# R2: 0111000101001101001101
# R3: 10110100010010000000111
#
# Estado 114:
# R1: 1001100011101110000
# R2: 1011100010100110100110
# R3: 11011010001001000000011
#
# Estado 115:
# R1: 1100110001110111000
# R2: 1101110001010011010011
# R3: 01101101000100100000001
#
# Estado 116:
# R1: 1110011000111011100
# R2: 0110111000101001101001
# R3: 00110110100010010000000
#
# Estado 117:
# R1: 1111001100011101110
# R2: 0110111000101001101001
# R3: 00011011010001001000000
#
# Estado 118:
# R1: 1111100110001110111
# R2: 0110111000101001101001
# R3: 10001101101000100100000
#
# Estado 119:
# R1: 0111110011000111011
# R2: 1011011100010100110100
# R3: 11000110110100010010000
#
# Estado 120:
# R1: 0111110011000111011
# R2: 0101101110001010011010
# R3: 01100011011010001001000
#
# Estado 121:
# R1: 1011111001100011101
# R2: 0101101110001010011010
# R3: 10110001101101000100100
#
# Estado 122:
# R1: 0101111100110001110
# R2: 1010110111000101001101
# R3: 10110001101101000100100
#
# Estado 123:
# R1: 0010111110011000111
# R2: 1101011011100010100110
# R3: 10110001101101000100100
#
# Estado 124:
# R1: 1001011111001100011
# R2: 1110101101110001010011
# R3: 01011000110110100010010
#
# Estado 125:
# R1: 1100101111100110001
# R2: 0111010110111000101001
# R3: 01011000110110100010010
#
# Estado 126:
# R1: 0110010111110011000
# R2: 1011101011011100010100
# R3: 01011000110110100010010
#
# Estado 127:
# R1: 0110010111110011000
# R2: 0101110101101110001010
# R3: 10101100011011010001001
#
# Estado 128:
# R1: 0011001011111001100
# R2: 1010111010110111000101
# R3: 11010110001101101000100
#
# Estado 129:
# R1: 1001100101111100110
# R2: 1101011101011011100010
# R3: 11101011000110110100010
#
# Estado 130:
# R1: 1100110010111110011
# R2: 1110101110101101110001
# R3: 01110101100011011010001
#
# Estado 131:
# R1: 1110011001011111001
# R2: 1111010111010110111000
# R3: 01110101100011011010001
#
# Estado 132:
# R1: 0111001100101111100
# R2: 0111101011101011011100
# R3: 00111010110001101101000
#
# Estado 133:
# R1: 0011100110010111110
# R2: 0111101011101011011100
# R3: 00011101011000110110100
#
# Estado 134:
# R1: 1001110011001011111
# R2: 0011110101110101101110
# R3: 00001110101100011011010
#
# Estado 135:
# R1: 1100111001100101111
# R2: 1001111010111010110111
# R3: 10000111010110001101101
#
# Estado 136:
# R1: 0110011100110010111
# R2: 1001111010111010110111
# R3: 11000011101011000110110
#
# Estado 137:
# R1: 0110011100110010111
# R2: 0100111101011101011011
# R3: 11100001110101100011011
#
# Estado 138:
# R1: 1011001110011001011
# R2: 0010011110101110101101
# R3: 11110000111010110001101
#
# Estado 139:
# R1: 0101100111001100101
# R2: 1001001111010111010110
# R3: 01111000011101011000110
#
# Estado 140:
# R1: 1010110011100110010
# R2: 1001001111010111010110
# R3: 00111100001110101100011
#
# Estado 141:
# R1: 0101011001110011001
# R2: 1001001111010111010110
# R3: 00011110000111010110001
#
# Estado 142:
# R1: 1010101100111001100
# R2: 1100100111101011101011
# R3: 10001111000011101011000
#
# Estado 143:
# R1: 1101010110011100110
# R2: 1100100111101011101011
# R3: 11000111100001110101100
#
# Estado 144:
# R1: 1110101011001110011
# R2: 0110010011110101110101
# R3: 11000111100001110101100
#
# Estado 145:
# R1: 1111010101100111001
# R2: 1011001001111010111010
# R3: 11000111100001110101100
#
# Estado 146:
# R1: 0111101010110011100
# R2: 1011001001111010111010
# R3: 01100011110000111010110
#
# Estado 147:
# R1: 1011110101011001110
# R2: 1101100100111101011101
# R3: 01100011110000111010110
#
# Estado 148:
# R1: 0101111010101100111
# R2: 1101100100111101011101
# R3: 10110001111000011101011
#
# Estado 149:
# R1: 0010111101010110011
# R2: 1110110010011110101110
# R3: 11011000111100001110101
#
# Estado 150:
# R1: 1001011110101011001
# R2: 1111011001001111010111
# R3: 11011000111100001110101
#
# Estado 151:
# R1: 1100101111010101100
# R2: 1111011001001111010111
# R3: 01101100011110000111010
#
# Estado 152:
# R1: 0110010111101010110
# R2: 1111011001001111010111
# R3: 10110110001111000011101
#
# Estado 153:
# R1: 0011001011110101011
# R2: 1111011001001111010111
# R3: 01011011000111100001110
#
# Estado 154:
# R1: 0011001011110101011
# R2: 0111101100100111101011
# R3: 10101101100011110000111
#
# Estado 155:
# R1: 1001100101111010101
# R2: 0011110110010011110101
# R3: 10101101100011110000111
#
# Estado 156:
# R1: 0100110010111101010
# R2: 1001111011001001111010
# R3: 01010110110001111000011
#
# Estado 157:
# R1: 0100110010111101010
# R2: 1100111101100100111101
# R3: 00101011011000111100001
#
# Estado 158:
# R1: 0010011001011110101
# R2: 1110011110110010011110
# R3: 00010101101100011110000
#
# Estado 159:
# R1: 0010011001011110101
# R2: 1111001111011001001111
# R3: 10001010110110001111000
#
# Estado 160:
# R1: 1001001100101111010
# R2: 0111100111101100100111
# R3: 01000101011011000111100
#
# Estado 161:
# R1: 1001001100101111010
# R2: 0011110011110110010011
# R3: 00100010101101100011110
#
# Estado 162:
# R1: 1001001100101111010
# R2: 0001111001111011001001
# R3: 00010001010110110001111
#
# Estado 163:
# R1: 0100100110010111101
# R2: 0001111001111011001001
# R3: 00001000101011011000111
#
# Estado 164:
# R1: 1010010011001011110
# R2: 1000111100111101100100
# R3: 10000100010101101100011
#
# Estado 165:
# R1: 0101001001100101111
# R2: 0100011110011110110010
# R3: 10000100010101101100011
#
# Estado 166:
# R1: 0010100100110010111
# R2: 1010001111001111011001
# R3: 01000010001010110110001
#
# Estado 167:
# R1: 1001010010011001011
# R2: 1101000111100111101100
# R3: 01000010001010110110001
#
# Estado 168:
# R1: 0100101001001100101
# R2: 0110100011110011110110
# R3: 10100001000101011011000
#
# Estado 169:
# R1: 1010010100100110010
# R2: 0110100011110011110110
# R3: 11010000100010101101100
#
# Estado 170:
# R1: 0101001010010011001
# R2: 0110100011110011110110
# R3: 11101000010001010110110
#
# Estado 171:
# R1: 1010100101001001100
# R2: 1011010001111001111011
# R3: 11101000010001010110110
#
# Estado 172:
# R1: 1101010010100100110
# R2: 1011010001111001111011
# R3: 01110100001000101011011
#
# Estado 173:
# R1: 1110101001010010011
# R2: 0101101000111100111101
# R3: 00111010000100010101101
#
# Estado 174:
# R1: 0111010100101001001
# R2: 0101101000111100111101
# R3: 00011101000010001010110
#
# Estado 175:
# R1: 1011101010010100100
# R2: 0101101000111100111101
# R3: 10001110100001000101011
#
# Estado 176:
# R1: 0101110101001010010
# R2: 1010110100011110011110
# R3: 10001110100001000101011
#
# Estado 177:
# R1: 1010111010100101001
# R2: 1101011010001111001111
# R3: 01000111010000100010101
#
# Estado 178:
# R1: 1010111010100101001
# R2: 0110101101000111100111
# R3: 10100011101000010001010
#
# Estado 179:
# R1: 0101011101010010100
# R2: 0110101101000111100111
# R3: 01010001110100001000101
#
# Estado 180:
# R1: 1010101110101001010
# R2: 0011010110100011110011
# R3: 10101000111010000100010
#
# Estado 181:
# R1: 1101010111010100101
# R2: 0001101011010001111001
# R3: 11010100011101000010001
#
# Estado 182:
# R1: 1110101011101010010
# R2: 0001101011010001111001
# R3: 11101010001110100001000
#
# Estado 183:
# R1: 1111010101110101001
# R2: 0001101011010001111001
# R3: 01110101000111010000100
#
# Estado 184:
# R1: 0111101010111010100
# R2: 1000110101101000111100
# R3: 00111010100011101000010
#
# Estado 185:
# R1: 1011110101011101010
# R2: 0100011010110100011110
# R3: 00111010100011101000010
#
# Estado 186:
# R1: 0101111010101110101
# R2: 0100011010110100011110
# R3: 10011101010001110100001
#
# === Geração da Keystream ===
# A iniciar geração de 228 bits da keystream...
#
# Estado 187:
# R1: 1010111101010111010
# R2: 1010001101011010001111
# R3: 10011101010001110100001
#
# Keystream gerada até agora:
# Em bits: 0
#
# Estado 188:
# R1: 0101011110101011101
# R2: 0101000110101101000111
# R3: 01001110101000111010000
#
# Keystream gerada até agora:
# Em bits: 00
#
# Estado 189:
# R1: 0010101111010101110
# R2: 0010100011010110100011
# R3: 00100111010100011101000
#
# Keystream gerada até agora:
# Em bits: 000
#
# Estado 190:
# R1: 0010101111010101110
# R2: 0001010001101011010001
# R3: 10010011101010001110100
#
# Keystream gerada até agora:
# Em bits: 0001
#
# Estado 191:
# R1: 1001010111101010111
# R2: 1000101000110101101000
# R3: 01001001110101000111010
#
# Keystream gerada até agora:
# Em bits: 00011
#
# Estado 192:
# R1: 1100101011110101011
# R2: 0100010100011010110100
# R3: 01001001110101000111010
#
# Keystream gerada até agora:
# Em bits: 000111
#
# Estado 193:
# R1: 1100101011110101011
# R2: 0010001010001101011010
# R3: 00100100111010100011101
#
# Keystream gerada até agora:
# Em bits: 0001111
#
# Estado 194:
# R1: 1110010101111010101
# R2: 0010001010001101011010
# R3: 00010010011101010001110
#
# Keystream gerada até agora:
# Em bits: 00011110
# Em bytes (hex): 1e
# Número de bytes gerados: 1
#
# Estado 195:
# R1: 0111001010111101010
# R2: 1001000101000110101101
# R3: 00010010011101010001110
#
# Keystream gerada até agora:
# Em bits: 00011110 1
# Em bytes (hex): 1e
# Número de bytes gerados: 1
#
# Estado 196:
# R1: 0011100101011110101
# R2: 1001000101000110101101
# R3: 00001001001110101000111
#
# Keystream gerada até agora:
# Em bits: 00011110 11
# Em bytes (hex): 1e
# Número de bytes gerados: 1
#
# Estado 197:
# R1: 1001110010101111010
# R2: 1100100010100011010110
# R3: 00001001001110101000111
#
# Keystream gerada até agora:
# Em bits: 00011110 111
# Em bytes (hex): 1e
# Número de bytes gerados: 1
#
# Estado 198:
# R1: 0100111001010111101
# R2: 1110010001010001101011
# R3: 00000100100111010100011
#
# Keystream gerada até agora:
# Em bits: 00011110 1111
# Em bytes (hex): 1e
# Número de bytes gerados: 1
#
# Estado 199:
# R1: 1010011100101011110
# R2: 0111001000101000110101
# R3: 00000010010011101010001
#
# Keystream gerada até agora:
# Em bits: 00011110 11111
# Em bytes (hex): 1e
# Número de bytes gerados: 1
#
# Estado 200:
# R1: 0101001110010101111
# R2: 0111001000101000110101
# R3: 10000001001001110101000
#
# Keystream gerada até agora:
# Em bits: 00011110 111110
# Em bytes (hex): 1e
# Número de bytes gerados: 1
#
# Estado 201:
# R1: 0010100111001010111
# R2: 1011100100010100011010
# R3: 11000000100100111010100
#
# Keystream gerada até agora:
# Em bits: 00011110 1111100
# Em bytes (hex): 1e
# Número de bytes gerados: 1
#
# Estado 202:
# R1: 0010100111001010111
# R2: 1101110010001010001101
# R3: 11100000010010011101010
#
# Keystream gerada até agora:
# Em bits: 00011110 11111001
# Em bytes (hex): 1ef9
# Número de bytes gerados: 2
#
# Estado 203:
# R1: 0010100111001010111
# R2: 1110111001000101000110
# R3: 11110000001001001110101
#
# Keystream gerada até agora:
# Em bits: 00011110 11111001 0
# Em bytes (hex): 1ef9
# Número de bytes gerados: 2
#
# Estado 204:
# R1: 1001010011100101011
# R2: 1110111001000101000110
# R3: 01111000000100100111010
#
# Keystream gerada até agora:
# Em bits: 00011110 11111001 00
# Em bytes (hex): 1ef9
# Número de bytes gerados: 2
#
# Estado 205:
# R1: 1001010011100101011
# R2: 1111011100100010100011
# R3: 10111100000010010011101
#
# Keystream gerada até agora:
# Em bits: 00011110 11111001 001
# Em bytes (hex): 1ef9
# Número de bytes gerados: 2
#
# Estado 206:
# R1: 1100101001110010101
# R2: 0111101110010001010001
# R3: 10111100000010010011101
#
# Keystream gerada até agora:
# Em bits: 00011110 11111001 0011
# Em bytes (hex): 1ef9
# Número de bytes gerados: 2
#
# Estado 207:
# R1: 0110010100111001010
# R2: 1011110111001000101000
# R3: 01011110000001001001110
#
# Keystream gerada até agora:
# Em bits: 00011110 11111001 00111
# Em bytes (hex): 1ef9
# Número de bytes gerados: 2
#
# Estado 208:
# R1: 1011001010011100101
# R2: 0101111011100100010100
# R3: 00101111000000100100111
#
# Keystream gerada até agora:
# Em bits: 00011110 11111001 001110
# Em bytes (hex): 1ef9
# Número de bytes gerados: 2
#
# Estado 209:
# R1: 1101100101001110010
# R2: 0010111101110010001010
# R3: 00101111000000100100111
#
# Keystream gerada até agora:
# Em bits: 00011110 11111001 0011100
# Em bytes (hex): 1ef9
# Número de bytes gerados: 2
#
# Estado 210:
# R1: 0110110010100111001
# R2: 0010111101110010001010
# R3: 00010111100000010010011
#
# Keystream gerada até agora:
# Em bits: 00011110 11111001 00111001
# Em bytes (hex): 1ef939
# Número de bytes gerados: 3
#
# Estado 211:
# R1: 0011011001010011100
# R2: 1001011110111001000101
# R3: 00010111100000010010011
#
# Keystream gerada até agora:
# Em bits: 00011110 11111001 00111001 0
# Em bytes (hex): 1ef939
# Número de bytes gerados: 3
#
# Estado 212:
# R1: 1001101100101001110
# R2: 1001011110111001000101
# R3: 10001011110000001001001
#
# Keystream gerada até agora:
# Em bits: 00011110 11111001 00111001 00
# Em bytes (hex): 1ef939
# Número de bytes gerados: 3
#
# Estado 213:
# R1: 0100110110010100111
# R2: 1001011110111001000101
# R3: 01000101111000000100100
#
# Keystream gerada até agora:
# Em bits: 00011110 11111001 00111001 000
# Em bytes (hex): 1ef939
# Número de bytes gerados: 3
#
# Estado 214:
# R1: 0010011011001010011
# R2: 1100101111011100100010
# R3: 00100010111100000010010
#
# Keystream gerada até agora:
# Em bits: 00011110 11111001 00111001 0000
# Em bytes (hex): 1ef939
# Número de bytes gerados: 3
#
# Estado 215:
# R1: 0001001101100101001
# R2: 1100101111011100100010
# R3: 10010001011110000001001
#
# Keystream gerada até agora:
# Em bits: 00011110 11111001 00111001 00001
# Em bytes (hex): 1ef939
# Número de bytes gerados: 3
#
# Estado 216:
# R1: 0000100110110010100
# R2: 1110010111101110010001
# R3: 10010001011110000001001
#
# Keystream gerada até agora:
# Em bits: 00011110 11111001 00111001 000010
# Em bytes (hex): 1ef939
# Número de bytes gerados: 3
#
# Estado 217:
# R1: 1000010011011001010
# R2: 1111001011110111001000
# R3: 01001000101111000000100
#
# Keystream gerada até agora:
# Em bits: 00011110 11111001 00111001 0000100
# Em bytes (hex): 1ef939
# Número de bytes gerados: 3
#
# Estado 218:
# R1: 1100001001101100101
# R2: 0111100101111011100100
# R3: 10100100010111100000010
#
# Keystream gerada até agora:
# Em bits: 00011110 11111001 00111001 00001000
# Em bytes (hex): 1ef93908
# Número de bytes gerados: 4
#
# Estado 219:
# R1: 1110000100110110010
# R2: 0111100101111011100100
# R3: 11010010001011110000001
#
# Keystream gerada até agora:
# Em bits: 00011110 11111001 00111001 00001000 1
# Em bytes (hex): 1ef93908
# Número de bytes gerados: 4
#
# Estado 220:
# R1: 1110000100110110010
# R2: 0011110010111101110010
# R3: 11101001000101111000000
#
# Keystream gerada até agora:
# Em bits: 00011110 11111001 00111001 00001000 11
# Em bytes (hex): 1ef93908
# Número de bytes gerados: 4
#
# Estado 221:
# R1: 0111000010011011001
# R2: 0011110010111101110010
# R3: 11110100100010111100000
#
# Keystream gerada até agora:
# Em bits: 00011110 11111001 00111001 00001000 110
# Em bytes (hex): 1ef93908
# Número de bytes gerados: 4
#
# Estado 222:
# R1: 1011100001001101100
# R2: 1001111001011110111001
# R3: 11110100100010111100000
#
# Keystream gerada até agora:
# Em bits: 00011110 11111001 00111001 00001000 1101
# Em bytes (hex): 1ef93908
# Número de bytes gerados: 4
#
# Estado 223:
# R1: 0101110000100110110
# R2: 1100111100101111011100
# R3: 01111010010001011110000
#
# Keystream gerada até agora:
# Em bits: 00011110 11111001 00111001 00001000 11011
# Em bytes (hex): 1ef93908
# Número de bytes gerados: 4
#
# Estado 224:
# R1: 1010111000010011011
# R2: 1100111100101111011100
# R3: 00111101001000101111000
#
# Keystream gerada até agora:
# Em bits: 00011110 11111001 00111001 00001000 110110
# Em bytes (hex): 1ef93908
# Número de bytes gerados: 4
#
# Estado 225:
# R1: 1010111000010011011
# R2: 0110011110010111101110
# R3: 10011110100100010111100
#
# Keystream gerada até agora:
# Em bits: 00011110 11111001 00111001 00001000 1101101
# Em bytes (hex): 1ef93908
# Número de bytes gerados: 4
#
# Estado 226:
# R1: 0101011100001001101
# R2: 1011001111001011110111
# R3: 11001111010010001011110
#
# Keystream gerada até agora:
# Em bits: 00011110 11111001 00111001 00001000 11011011
# Em bytes (hex): 1ef93908db
# Número de bytes gerados: 5
#
# Estado 227:
# R1: 0010101110000100110
# R2: 0101100111100101111011
# R3: 11100111101001000101111
#
# Keystream gerada até agora:
# Em bits: 00011110 11111001 00111001 00001000 11011011 0
# Em bytes (hex): 1ef93908db
# Número de bytes gerados: 5
#
# Estado 228:
# R1: 1001010111000010011
# R2: 0010110011110010111101
# R3: 01110011110100100010111
#
# Keystream gerada até agora:
# Em bits: 00011110 11111001 00111001 00001000 11011011 00
# Em bytes (hex): 1ef93908db
# Número de bytes gerados: 5
#
# Estado 229:
# R1: 0100101011100001001
# R2: 1001011001111001011110
# R3: 01110011110100100010111
#
# Keystream gerada até agora:
# Em bits: 00011110 11111001 00111001 00001000 11011011 001
# Em bytes (hex): 1ef93908db
# Número de bytes gerados: 5
#
# Estado 230:
# R1: 1010010101110000100
# R2: 1100101100111100101111
# R3: 01110011110100100010111
#
# Keystream gerada até agora:
# Em bits: 00011110 11111001 00111001 00001000 11011011 0010
# Em bytes (hex): 1ef93908db
# Número de bytes gerados: 5
#
# Estado 231:
# R1: 1101001010111000010
# R2: 1100101100111100101111
# R3: 00111001111010010001011
#
# Keystream gerada até agora:
# Em bits: 00011110 11111001 00111001 00001000 11011011 00100
# Em bytes (hex): 1ef93908db
# Número de bytes gerados: 5
#
# Estado 232:
# R1: 1110100101011100001
# R2: 0110010110011110010111
# R3: 10011100111101001000101
#
# Keystream gerada até agora:
# Em bits: 00011110 11111001 00111001 00001000 11011011 001000
# Em bytes (hex): 1ef93908db
# Número de bytes gerados: 5
#
# Estado 233:
# R1: 0111010010101110000
# R2: 0011001011001111001011
# R3: 10011100111101001000101
#
# Keystream gerada até agora:
# Em bits: 00011110 11111001 00111001 00001000 11011011 0010001
# Em bytes (hex): 1ef93908db
# Número de bytes gerados: 5
#
# Estado 234:
# R1: 1011101001010111000
# R2: 0011001011001111001011
# R3: 01001110011110100100010
#
# Keystream gerada até agora:
# Em bits: 00011110 11111001 00111001 00001000 11011011 00100010
# Em bytes (hex): 1ef93908db22
# Número de bytes gerados: 6
#
# Estado 235:
# R1: 1101110100101011100
# R2: 0001100101100111100101
# R3: 01001110011110100100010
#
# Keystream gerada até agora:
# Em bits: 00011110 11111001 00111001 00001000 11011011 00100010 1
# Em bytes (hex): 1ef93908db22
# Número de bytes gerados: 6
#
# Estado 236:
# R1: 1101110100101011100
# R2: 1000110010110011110010
# R3: 10100111001111010010001
#
# Keystream gerada até agora:
# Em bits: 00011110 11111001 00111001 00001000 11011011 00100010 11
# Em bytes (hex): 1ef93908db22
# Número de bytes gerados: 6
#
# Estado 237:
# R1: 1101110100101011100
# R2: 1100011001011001111001
# R3: 01010011100111101001000
#
# Keystream gerada até agora:
# Em bits: 00011110 11111001 00111001 00001000 11011011 00100010 111
# Em bytes (hex): 1ef93908db22
# Número de bytes gerados: 6
#
# Estado 238:
# R1: 1110111010010101110
# R2: 1110001100101100111100
# R3: 10101001110011110100100
#
# Keystream gerada até agora:
# Em bits: 00011110 11111001 00111001 00001000 11011011 00100010 1111
# Em bytes (hex): 1ef93908db22
# Número de bytes gerados: 6
#
# Estado 239:
# R1: 1111011101001010111
# R2: 0111000110010110011110
# R3: 10101001110011110100100
#
# Keystream gerada até agora:
# Em bits: 00011110 11111001 00111001 00001000 11011011 00100010 11110
# Em bytes (hex): 1ef93908db22
# Número de bytes gerados: 6
#
# Estado 240:
# R1: 1111101110100101011
# R2: 1011100011001011001111
# R3: 01010100111001111010010
#
# Keystream gerada até agora:
# Em bits: 00011110 11111001 00111001 00001000 11011011 00100010 111101
# Em bytes (hex): 1ef93908db22
# Número de bytes gerados: 6
#
# Estado 241:
# R1: 1111110111010010101
# R2: 1011100011001011001111
# R3: 10101010011100111101001
#
# Keystream gerada até agora:
# Em bits: 00011110 11111001 00111001 00001000 11011011 00100010 1111010
# Em bytes (hex): 1ef93908db22
# Número de bytes gerados: 6
#
# Estado 242:
# R1: 0111111011101001010
# R2: 1011100011001011001111
# R3: 11010101001110011110100
#
# Keystream gerada até agora:
# Em bits: 00011110 11111001 00111001 00001000 11011011 00100010 11110101
# Em bytes (hex): 1ef93908db22f5
# Número de bytes gerados: 7
#
# Estado 243:
# R1: 1011111101110100101
# R2: 1011100011001011001111
# R3: 01101010100111001111010
#
# Keystream gerada até agora:
# Em bits: 00011110 11111001 00111001 00001000 11011011 00100010 11110101 1
# Em bytes (hex): 1ef93908db22f5
# Número de bytes gerados: 7
#
# Estado 244:
# R1: 1101111110111010010
# R2: 0101110001100101100111
# R3: 10110101010011100111101
#
# Keystream gerada até agora:
# Em bits: 00011110 11111001 00111001 00001000 11011011 00100010 11110101 10
# Em bytes (hex): 1ef93908db22f5
# Número de bytes gerados: 7
#
# Estado 245:
# R1: 1110111111011101001
# R2: 0010111000110010110011
# R3: 10110101010011100111101
#
# Keystream gerada até agora:
# Em bits: 00011110 11111001 00111001 00001000 11011011 00100010 11110101 100
# Em bytes (hex): 1ef93908db22f5
# Número de bytes gerados: 7
#
# Estado 246:
# R1: 0111011111101110100
# R2: 0001011100011001011001
# R3: 10110101010011100111101
#
# Keystream gerada até agora:
# Em bits: 00011110 11111001 00111001 00001000 11011011 00100010 11110101 1001
# Em bytes (hex): 1ef93908db22f5
# Número de bytes gerados: 7
#
# Estado 247:
# R1: 0111011111101110100
# R2: 1000101110001100101100
# R3: 11011010101001110011110
#
# Keystream gerada até agora:
# Em bits: 00011110 11111001 00111001 00001000 11011011 00100010 11110101 10010
# Em bytes (hex): 1ef93908db22f5
# Número de bytes gerados: 7
#
# Estado 248:
# R1: 0011101111110111010
# R2: 1000101110001100101100
# R3: 01101101010100111001111
#
# Keystream gerada até agora:
# Em bits: 00011110 11111001 00111001 00001000 11011011 00100010 11110101 100100
# Em bytes (hex): 1ef93908db22f5
# Número de bytes gerados: 7
#
# Estado 249:
# R1: 0011101111110111010
# R2: 0100010111000110010110
# R3: 00110110101010011100111
#
# Keystream gerada até agora:
# Em bits: 00011110 11111001 00111001 00001000 11011011 00100010 11110101 1001001
# Em bytes (hex): 1ef93908db22f5
# Número de bytes gerados: 7
#
# Estado 250:
# R1: 0001110111111011101
# R2: 0100010111000110010110
# R3: 10011011010101001110011
#
# Keystream gerada até agora:
# Em bits: 00011110 11111001 00111001 00001000 11011011 00100010 11110101 10010011
# Em bytes (hex): 1ef93908db22f593
# Número de bytes gerados: 8
#
# Estado 251:
# R1: 0001110111111011101
# R2: 1010001011100011001011
# R3: 11001101101010100111001
#
# Keystream gerada até agora:
# Em bits: 00011110 11111001 00111001 00001000 11011011 00100010 11110101 10010011 0
# Em bytes (hex): 1ef93908db22f593
# Número de bytes gerados: 8
#
# Estado 252:
# R1: 0000111011111101110
# R2: 0101000101110001100101
# R3: 01100110110101010011100
#
# Keystream gerada até agora:
# Em bits: 00011110 11111001 00111001 00001000 11011011 00100010 11110101 10010011 01
# Em bytes (hex): 1ef93908db22f593
# Número de bytes gerados: 8
#
# Estado 253:
# R1: 1000011101111110111
# R2: 1010100010111000110010
# R3: 01100110110101010011100
#
# Keystream gerada até agora:
# Em bits: 00011110 11111001 00111001 00001000 11011011 00100010 11110101 10010011 011
# Em bytes (hex): 1ef93908db22f593
# Número de bytes gerados: 8
#
# Estado 254:
# R1: 0100001110111111011
# R2: 1010100010111000110010
# R3: 10110011011010101001110
#
# Keystream gerada até agora:
# Em bits: 00011110 11111001 00111001 00001000 11011011 00100010 11110101 10010011 0111
# Em bytes (hex): 1ef93908db22f593
# Número de bytes gerados: 8
#
# Estado 255:
# R1: 1010000111011111101
# R2: 1101010001011100011001
# R3: 11011001101101010100111
#
# Keystream gerada até agora:
# Em bits: 00011110 11111001 00111001 00001000 11011011 00100010 11110101 10010011 01111
# Em bytes (hex): 1ef93908db22f593
# Número de bytes gerados: 8
#
# Estado 256:
# R1: 1101000011101111110
# R2: 1101010001011100011001
# R3: 01101100110110101010011
#
# Keystream gerada até agora:
# Em bits: 00011110 11111001 00111001 00001000 11011011 00100010 11110101 10010011 011111
# Em bytes (hex): 1ef93908db22f593
# Número de bytes gerados: 8
#
# Estado 257:
# R1: 1101000011101111110
# R2: 1110101000101110001100
# R3: 00110110011011010101001
#
# Keystream gerada até agora:
# Em bits: 00011110 11111001 00111001 00001000 11011011 00100010 11110101 10010011 0111110
# Em bytes (hex): 1ef93908db22f593
# Número de bytes gerados: 8
#
# Estado 258:
# R1: 1110100001110111111
# R2: 0111010100010111000110
# R3: 10011011001101101010100
#
# Keystream gerada até agora:
# Em bits: 00011110 11111001 00111001 00001000 11011011 00100010 11110101 10010011 01111101
# Em bytes (hex): 1ef93908db22f5937d
# Número de bytes gerados: 9
#
# Estado 259:
# R1: 0111010000111011111
# R2: 1011101010001011100011
# R3: 10011011001101101010100
#
# Keystream gerada até agora:
# Em bits: 00011110 11111001 00111001 00001000 11011011 00100010 11110101 10010011 01111101 1
# Em bytes (hex): 1ef93908db22f5937d
# Número de bytes gerados: 9
#
# Estado 260:
# R1: 1011101000011101111
# R2: 0101110101000101110001
# R3: 10011011001101101010100
#
# Keystream gerada até agora:
# Em bits: 00011110 11111001 00111001 00001000 11011011 00100010 11110101 10010011 01111101 10
# Em bytes (hex): 1ef93908db22f5937d
# Número de bytes gerados: 9
#
# Estado 261:
# R1: 0101110100001110111
# R2: 1010111010100010111000
# R3: 10011011001101101010100
#
# Keystream gerada até agora:
# Em bits: 00011110 11111001 00111001 00001000 11011011 00100010 11110101 10010011 01111101 100
# Em bytes (hex): 1ef93908db22f5937d
# Número de bytes gerados: 9
#
# Estado 262:
# R1: 0101110100001110111
# R2: 0101011101010001011100
# R3: 01001101100110110101010
#
# Keystream gerada até agora:
# Em bits: 00011110 11111001 00111001 00001000 11011011 00100010 11110101 10010011 01111101 1001
# Em bytes (hex): 1ef93908db22f5937d
# Número de bytes gerados: 9
#
# Estado 263:
# R1: 0010111010000111011
# R2: 0010101110101000101110
# R3: 00100110110011011010101
#
# Keystream gerada até agora:
# Em bits: 00011110 11111001 00111001 00001000 11011011 00100010 11110101 10010011 01111101 10011
# Em bytes (hex): 1ef93908db22f5937d
# Número de bytes gerados: 9
#
# Estado 264:
# R1: 1001011101000011101
# R2: 1001010111010100010111
# R3: 00100110110011011010101
#
# Keystream gerada até agora:
# Em bits: 00011110 11111001 00111001 00001000 11011011 00100010 11110101 10010011 01111101 100110
# Em bytes (hex): 1ef93908db22f5937d
# Número de bytes gerados: 9
#
# Estado 265:
# R1: 0100101110100001110
# R2: 0100101011101010001011
# R3: 00010011011001101101010
#
# Keystream gerada até agora:
# Em bits: 00011110 11111001 00111001 00001000 11011011 00100010 11110101 10010011 01111101 1001101
# Em bytes (hex): 1ef93908db22f5937d
# Número de bytes gerados: 9
#
# Estado 266:
# R1: 0010010111010000111
# R2: 0010010101110101000101
# R3: 00001001101100110110101
#
# Keystream gerada até agora:
# Em bits: 00011110 11111001 00111001 00001000 11011011 00100010 11110101 10010011 01111101 10011011
# Em bytes (hex): 1ef93908db22f5937d9b
# Número de bytes gerados: 10
#
# Estado 267:
# R1: 1001001011101000011
# R2: 1001001010111010100010
# R3: 10000100110110011011010
#
# Keystream gerada até agora:
# Em bits: 00011110 11111001 00111001 00001000 11011011 00100010 11110101 10010011 01111101 10011011 1
# Em bytes (hex): 1ef93908db22f5937d9b
# Número de bytes gerados: 10
#
# Estado 268:
# R1: 0100100101110100001
# R2: 1100100101011101010001
# R3: 10000100110110011011010
#
# Keystream gerada até agora:
# Em bits: 00011110 11111001 00111001 00001000 11011011 00100010 11110101 10010011 01111101 10011011 11
# Em bytes (hex): 1ef93908db22f5937d9b
# Número de bytes gerados: 10
#
# Estado 269:
# R1: 0010010010111010000
# R2: 1110010010101110101000
# R3: 11000010011011001101101
#
# Keystream gerada até agora:
# Em bits: 00011110 11111001 00111001 00001000 11011011 00100010 11110101 10010011 01111101 10011011 110
# Em bytes (hex): 1ef93908db22f5937d9b
# Número de bytes gerados: 10
#
# Estado 270:
# R1: 0001001001011101000
# R2: 0111001001010111010100
# R3: 01100001001101100110110
#
# Keystream gerada até agora:
# Em bits: 00011110 11111001 00111001 00001000 11011011 00100010 11110101 10010011 01111101 10011011 1101
# Em bytes (hex): 1ef93908db22f5937d9b
# Número de bytes gerados: 10
#
# Estado 271:
# R1: 1000100100101110100
# R2: 0011100100101011101010
# R3: 01100001001101100110110
#
# Keystream gerada até agora:
# Em bits: 00011110 11111001 00111001 00001000 11011011 00100010 11110101 10010011 01111101 10011011 11010
# Em bytes (hex): 1ef93908db22f5937d9b
# Número de bytes gerados: 10
#
# Estado 272:
# R1: 1000100100101110100
# R2: 1001110010010101110101
# R3: 10110000100110110011011
#
# Keystream gerada até agora:
# Em bits: 00011110 11111001 00111001 00001000 11011011 00100010 11110101 10010011 01111101 10011011 110100
# Em bytes (hex): 1ef93908db22f5937d9b
# Número de bytes gerados: 10
#
# Estado 273:
# R1: 0100010010010111010
# R2: 1100111001001010111010
# R3: 01011000010011011001101
#
# Keystream gerada até agora:
# Em bits: 00011110 11111001 00111001 00001000 11011011 00100010 11110101 10010011 01111101 10011011 1101000
# Em bytes (hex): 1ef93908db22f5937d9b
# Número de bytes gerados: 10
#
# Estado 274:
# R1: 0100010010010111010
# R2: 1110011100100101011101
# R3: 00101100001001101100110
#
# Keystream gerada até agora:
# Em bits: 00011110 11111001 00111001 00001000 11011011 00100010 11110101 10010011 01111101 10011011 11010001
# Em bytes (hex): 1ef93908db22f5937d9bd1
# Número de bytes gerados: 11
#
# Estado 275:
# R1: 0010001001001011101
# R2: 1111001110010010101110
# R3: 00010110000100110110011
#
# Keystream gerada até agora:
# Em bits: 00011110 11111001 00111001 00001000 11011011 00100010 11110101 10010011 01111101 10011011 11010001 1
# Em bytes (hex): 1ef93908db22f5937d9bd1
# Número de bytes gerados: 11
#
# Estado 276:
# R1: 0001000100100101110
# R2: 1111100111001001010111
# R3: 00001011000010011011001
#
# Keystream gerada até agora:
# Em bits: 00011110 11111001 00111001 00001000 11011011 00100010 11110101 10010011 01111101 10011011 11010001 10
# Em bytes (hex): 1ef93908db22f5937d9bd1
# Número de bytes gerados: 11
#
# Estado 277:
# R1: 1000100010010010111
# R2: 0111110011100100101011
# R3: 00000101100001001101100
#
# Keystream gerada até agora:
# Em bits: 00011110 11111001 00111001 00001000 11011011 00100010 11110101 10010011 01111101 10011011 11010001 100
# Em bytes (hex): 1ef93908db22f5937d9bd1
# Número de bytes gerados: 11
#
# Estado 278:
# R1: 1100010001001001011
# R2: 0011111001110010010101
# R3: 00000101100001001101100
#
# Keystream gerada até agora:
# Em bits: 00011110 11111001 00111001 00001000 11011011 00100010 11110101 10010011 01111101 10011011 11010001 1000
# Em bytes (hex): 1ef93908db22f5937d9bd1
# Número de bytes gerados: 11
#
# Estado 279:
# R1: 0110001000100100101
# R2: 0011111001110010010101
# R3: 00000010110000100110110
#
# Keystream gerada até agora:
# Em bits: 00011110 11111001 00111001 00001000 11011011 00100010 11110101 10010011 01111101 10011011 11010001 10000
# Em bytes (hex): 1ef93908db22f5937d9bd1
# Número de bytes gerados: 11
#
# Estado 280:
# R1: 1011000100010010010
# R2: 0011111001110010010101
# R3: 00000001011000010011011
#
# Keystream gerada até agora:
# Em bits: 00011110 11111001 00111001 00001000 11011011 00100010 11110101 10010011 01111101 10011011 11010001 100000
# Em bytes (hex): 1ef93908db22f5937d9bd1
# Número de bytes gerados: 11
#
# Estado 281:
# R1: 1011000100010010010
# R2: 1001111100111001001010
# R3: 10000000101100001001101
#
# Keystream gerada até agora:
# Em bits: 00011110 11111001 00111001 00001000 11011011 00100010 11110101 10010011 01111101 10011011 11010001 1000000
# Em bytes (hex): 1ef93908db22f5937d9bd1
# Número de bytes gerados: 11
#
# Estado 282:
# R1: 1011000100010010010
# R2: 1100111110011100100101
# R3: 01000000010110000100110
#
# Keystream gerada até agora:
# Em bits: 00011110 11111001 00111001 00001000 11011011 00100010 11110101 10010011 01111101 10011011 11010001 10000001
# Em bytes (hex): 1ef93908db22f5937d9bd181
# Número de bytes gerados: 12
#
# Estado 283:
# R1: 1101100010001001001
# R2: 1110011111001110010010
# R3: 00100000001011000010011
#
# Keystream gerada até agora:
# Em bits: 00011110 11111001 00111001 00001000 11011011 00100010 11110101 10010011 01111101 10011011 11010001 10000001 1
# Em bytes (hex): 1ef93908db22f5937d9bd181
# Número de bytes gerados: 12
#
# Estado 284:
# R1: 1110110001000100100
# R2: 1110011111001110010010
# R3: 00010000000101100001001
#
# Keystream gerada até agora:
# Em bits: 00011110 11111001 00111001 00001000 11011011 00100010 11110101 10010011 01111101 10011011 11010001 10000001 10
# Em bytes (hex): 1ef93908db22f5937d9bd181
# Número de bytes gerados: 12
#
# Estado 285:
# R1: 0111011000100010010
# R2: 1111001111100111001001
# R3: 10001000000010110000100
#
# Keystream gerada até agora:
# Em bits: 00011110 11111001 00111001 00001000 11011011 00100010 11110101 10010011 01111101 10011011 11010001 10000001 101
# Em bytes (hex): 1ef93908db22f5937d9bd181
# Número de bytes gerados: 12
#
# Estado 286:
# R1: 1011101100010001001
# R2: 1111001111100111001001
# R3: 11000100000001011000010
#
# Keystream gerada até agora:
# Em bits: 00011110 11111001 00111001 00001000 11011011 00100010 11110101 10010011 01111101 10011011 11010001 10000001 1011
# Em bytes (hex): 1ef93908db22f5937d9bd181
# Número de bytes gerados: 12
#
# Estado 287:
# R1: 1101110110001000100
# R2: 1111001111100111001001
# R3: 11100010000000101100001
#
# Keystream gerada até agora:
# Em bits: 00011110 11111001 00111001 00001000 11011011 00100010 11110101 10010011 01111101 10011011 11010001 10000001 10110
# Em bytes (hex): 1ef93908db22f5937d9bd181
# Número de bytes gerados: 12
#
# Estado 288:
# R1: 1110111011000100010
# R2: 1111100111110011100100
# R3: 11100010000000101100001
#
# Keystream gerada até agora:
# Em bits: 00011110 11111001 00111001 00001000 11011011 00100010 11110101 10010011 01111101 10011011 11010001 10000001 101100
# Em bytes (hex): 1ef93908db22f5937d9bd181
# Número de bytes gerados: 12
#
# Estado 289:
# R1: 0111011101100010001
# R2: 0111110011111001110010
# R3: 11100010000000101100001
#
# Keystream gerada até agora:
# Em bits: 00011110 11111001 00111001 00001000 11011011 00100010 11110101 10010011 01111101 10011011 11010001 10000001 1011001
# Em bytes (hex): 1ef93908db22f5937d9bd181
# Número de bytes gerados: 12
#
# Estado 290:
# R1: 1011101110110001000
# R2: 0111110011111001110010
# R3: 11110001000000010110000
#
# Keystream gerada até agora:
# Em bits: 00011110 11111001 00111001 00001000 11011011 00100010 11110101 10010011 01111101 10011011 11010001 10000001 10110010
# Em bytes (hex): 1ef93908db22f5937d9bd181b2
# Número de bytes gerados: 13
#
# Estado 291:
# R1: 0101110111011000100
# R2: 1011111001111100111001
# R3: 11110001000000010110000
#
# Keystream gerada até agora:
# Em bits: 00011110 11111001 00111001 00001000 11011011 00100010 11110101 10010011 01111101 10011011 11010001 10000001 10110010 0
# Em bytes (hex): 1ef93908db22f5937d9bd181b2
# Número de bytes gerados: 13
#
# Estado 292:
# R1: 1010111011101100010
# R2: 1101111100111110011100
# R3: 11110001000000010110000
#
# Keystream gerada até agora:
# Em bits: 00011110 11111001 00111001 00001000 11011011 00100010 11110101 10010011 01111101 10011011 11010001 10000001 10110010 01
# Em bytes (hex): 1ef93908db22f5937d9bd181b2
# Número de bytes gerados: 13
#
# Estado 293:
# R1: 0101011101110110001
# R2: 0110111110011111001110
# R3: 11110001000000010110000
#
# Keystream gerada até agora:
# Em bits: 00011110 11111001 00111001 00001000 11011011 00100010 11110101 10010011 01111101 10011011 11010001 10000001 10110010 010
# Em bytes (hex): 1ef93908db22f5937d9bd181b2
# Número de bytes gerados: 13
#
# Estado 294:
# R1: 0010101110111011000
# R2: 1011011111001111100111
# R3: 11111000100000001011000
#
# Keystream gerada até agora:
# Em bits: 00011110 11111001 00111001 00001000 11011011 00100010 11110101 10010011 01111101 10011011 11010001 10000001 10110010 0101
# Em bytes (hex): 1ef93908db22f5937d9bd181b2
# Número de bytes gerados: 13
#
# Estado 295:
# R1: 0010101110111011000
# R2: 0101101111100111110011
# R3: 01111100010000000101100
#
# Keystream gerada até agora:
# Em bits: 00011110 11111001 00111001 00001000 11011011 00100010 11110101 10010011 01111101 10011011 11010001 10000001 10110010 01011
# Em bytes (hex): 1ef93908db22f5937d9bd181b2
# Número de bytes gerados: 13
#
# Estado 296:
# R1: 0001010111011101100
# R2: 0010110111110011111001
# R3: 01111100010000000101100
#
# Keystream gerada até agora:
# Em bits: 00011110 11111001 00111001 00001000 11011011 00100010 11110101 10010011 01111101 10011011 11010001 10000001 10110010 010111
# Em bytes (hex): 1ef93908db22f5937d9bd181b2
# Número de bytes gerados: 13
#
# Estado 297:
# R1: 0000101011101110110
# R2: 1001011011111001111100
# R3: 01111100010000000101100
#
# Keystream gerada até agora:
# Em bits: 00011110 11111001 00111001 00001000 11011011 00100010 11110101 10010011 01111101 10011011 11010001 10000001 10110010 0101111
# Em bytes (hex): 1ef93908db22f5937d9bd181b2
# Número de bytes gerados: 13
#
# Estado 298:
# R1: 1000010101110111011
# R2: 0100101101111100111110
# R3: 01111100010000000101100
#
# Keystream gerada até agora:
# Em bits: 00011110 11111001 00111001 00001000 11011011 00100010 11110101 10010011 01111101 10011011 11010001 10000001 10110010 01011110
# Em bytes (hex): 1ef93908db22f5937d9bd181b25e
# Número de bytes gerados: 14
#
# Estado 299:
# R1: 1100001010111011101
# R2: 0100101101111100111110
# R3: 10111110001000000010110
#
# Keystream gerada até agora:
# Em bits: 00011110 11111001 00111001 00001000 11011011 00100010 11110101 10010011 01111101 10011011 11010001 10000001 10110010 01011110 1
# Em bytes (hex): 1ef93908db22f5937d9bd181b25e
# Número de bytes gerados: 14
#
# Estado 300:
# R1: 0110000101011101110
# R2: 1010010110111110011111
# R3: 01011111000100000001011
#
# Keystream gerada até agora:
# Em bits: 00011110 11111001 00111001 00001000 11011011 00100010 11110101 10010011 01111101 10011011 11010001 10000001 10110010 01011110 11
# Em bytes (hex): 1ef93908db22f5937d9bd181b25e
# Número de bytes gerados: 14
#
# Estado 301:
# R1: 1011000010101110111
# R2: 1010010110111110011111
# R3: 10101111100010000000101
#
# Keystream gerada até agora:
# Em bits: 00011110 11111001 00111001 00001000 11011011 00100010 11110101 10010011 01111101 10011011 11010001 10000001 10110010 01011110 110
# Em bytes (hex): 1ef93908db22f5937d9bd181b25e
# Número de bytes gerados: 14
#
# Estado 302:
# R1: 0101100001010111011
# R2: 0101001011011111001111
# R3: 10101111100010000000101
#
# Keystream gerada até agora:
# Em bits: 00011110 11111001 00111001 00001000 11011011 00100010 11110101 10010011 01111101 10011011 11010001 10000001 10110010 01011110 1101
# Em bytes (hex): 1ef93908db22f5937d9bd181b25e
# Número de bytes gerados: 14
#
# Estado 303:
# R1: 1010110000101011101
# R2: 0010100101101111100111
# R3: 11010111110001000000010
#
# Keystream gerada até agora:
# Em bits: 00011110 11111001 00111001 00001000 11011011 00100010 11110101 10010011 01111101 10011011 11010001 10000001 10110010 01011110 11011
# Em bytes (hex): 1ef93908db22f5937d9bd181b25e
# Número de bytes gerados: 14
#
# Estado 304:
# R1: 0101011000010101110
# R2: 0010100101101111100111
# R3: 01101011111000100000001
#
# Keystream gerada até agora:
# Em bits: 00011110 11111001 00111001 00001000 11011011 00100010 11110101 10010011 01111101 10011011 11010001 10000001 10110010 01011110 110110
# Em bytes (hex): 1ef93908db22f5937d9bd181b25e
# Número de bytes gerados: 14
#
# Estado 305:
# R1: 0101011000010101110
# R2: 0001010010110111110011
# R3: 00110101111100010000000
#
# Keystream gerada até agora:
# Em bits: 00011110 11111001 00111001 00001000 11011011 00100010 11110101 10010011 01111101 10011011 11010001 10000001 10110010 01011110 1101100
# Em bytes (hex): 1ef93908db22f5937d9bd181b25e
# Número de bytes gerados: 14
#
# Estado 306:
# R1: 0101011000010101110
# R2: 0000101001011011111001
# R3: 10011010111110001000000
#
# Keystream gerada até agora:
# ...
#
# Keystream gerada até agora:
# Em bits: 00011110 11111001 00111001 00001000 11011011 00100010 11110101 10010011 01111101 10011011 11010001 10000001 10110010 01011110 11011001 11100101 11001001 10011111 00111111 11001010 01010100 11101100 11000110 11111111 010
# Em bytes (hex): 1ef93908db22f5937d9bd181b25ed9e5c99f3fca54ecc6ff
# Número de bytes gerados: 24
#
# Estado 382:
# R1: 0111011001100111010
# R2: 1010101110010001001000
# R3: 01111111011101001100010
#
# Keystream gerada até agora:
# Em bits: 00011110 11111001 00111001 00001000 11011011 00100010 11110101 10010011 01111101 10011011 11010001 10000001 10110010 01011110 11011001 11100101 11001001 10011111 00111111 11001010 01010100 11101100 11000110 11111111 0100
# Em bytes (hex): 1ef93908db22f5937d9bd181b25ed9e5c99f3fca54ecc6ff
# Número de bytes gerados: 24
#
# Estado 383:
# R1: 0011101100110011101
# R2: 0101010111001000100100
# R3: 01111111011101001100010
#
# Keystream gerada até agora:
# Em bits: 00011110 11111001 00111001 00001000 11011011 00100010 11110101 10010011 01111101 10011011 11010001 10000001 10110010 01011110 11011001 11100101 11001001 10011111 00111111 11001010 01010100 11101100 11000110 11111111 01000
# Em bytes (hex): 1ef93908db22f5937d9bd181b25ed9e5c99f3fca54ecc6ff
# Número de bytes gerados: 24
#
# Estado 384:
# R1: 0001110110011001110
# R2: 0010101011100100010010
# R3: 01111111011101001100010
#
# Keystream gerada até agora:
# Em bits: 00011110 11111001 00111001 00001000 11011011 00100010 11110101 10010011 01111101 10011011 11010001 10000001 10110010 01011110 11011001 11100101 11001001 10011111 00111111 11001010 01010100 11101100 11000110 11111111 010001
# Em bytes (hex): 1ef93908db22f5937d9bd181b25ed9e5c99f3fca54ecc6ff
# Número de bytes gerados: 24
#
# Estado 385:
# R1: 0000111011001100111
# R2: 1001010101110010001001
# R3: 00111111101110100110001
#
# Keystream gerada até agora:
# Em bits: 00011110 11111001 00111001 00001000 11011011 00100010 11110101 10010011 01111101 10011011 11010001 10000001 10110010 01011110 11011001 11100101 11001001 10011111 00111111 11001010 01010100 11101100 11000110 11111111 0100010
# Em bytes (hex): 1ef93908db22f5937d9bd181b25ed9e5c99f3fca54ecc6ff
# Número de bytes gerados: 24
#
# Estado 386:
# R1: 0000011101100110011
# R2: 1100101010111001000100
# R3: 00011111110111010011000
#
# Keystream gerada até agora:
# Em bits: 00011110 11111001 00111001 00001000 11011011 00100010 11110101 10010011 01111101 10011011 11010001 10000001 10110010 01011110 11011001 11100101 11001001 10011111 00111111 11001010 01010100 11101100 11000110 11111111 01000101
# Em bytes (hex): 1ef93908db22f5937d9bd181b25ed9e5c99f3fca54ecc6ff45
# Número de bytes gerados: 25
#
# Estado 387:
# R1: 1000001110110011001
# R2: 1100101010111001000100
# R3: 10001111111011101001100
#
# Keystream gerada até agora:
# Em bits: 00011110 11111001 00111001 00001000 11011011 00100010 11110101 10010011 01111101 10011011 11010001 10000001 10110010 01011110 11011001 11100101 11001001 10011111 00111111 11001010 01010100 11101100 11000110 11111111 01000101 1
# Em bytes (hex): 1ef93908db22f5937d9bd181b25ed9e5c99f3fca54ecc6ff45
# Número de bytes gerados: 25
#
# Estado 388:
# R1: 1100000111011001100
# R2: 0110010101011100100010
# R3: 01000111111101110100110
#
# Keystream gerada até agora:
# Em bits: 00011110 11111001 00111001 00001000 11011011 00100010 11110101 10010011 01111101 10011011 11010001 10000001 10110010 01011110 11011001 11100101 11001001 10011111 00111111 11001010 01010100 11101100 11000110 11111111 01000101 11
# Em bytes (hex): 1ef93908db22f5937d9bd181b25ed9e5c99f3fca54ecc6ff45
# Número de bytes gerados: 25
#
# Estado 389:
# R1: 1110000011101100110
# R2: 0110010101011100100010
# R3: 10100011111110111010011
#
# Keystream gerada até agora:
# Em bits: 00011110 11111001 00111001 00001000 11011011 00100010 11110101 10010011 01111101 10011011 11010001 10000001 10110010 01011110 11011001 11100101 11001001 10011111 00111111 11001010 01010100 11101100 11000110 11111111 01000101 110
# Em bytes (hex): 1ef93908db22f5937d9bd181b25ed9e5c99f3fca54ecc6ff45
# Número de bytes gerados: 25
#
# Estado 390:
# R1: 1111000001110110011
# R2: 0110010101011100100010
# R3: 11010001111111011101001
#
# Keystream gerada até agora:
# Em bits: 00011110 11111001 00111001 00001000 11011011 00100010 11110101 10010011 01111101 10011011 11010001 10000001 10110010 01011110 11011001 11100101 11001001 10011111 00111111 11001010 01010100 11101100 11000110 11111111 01000101 1101
# Em bytes (hex): 1ef93908db22f5937d9bd181b25ed9e5c99f3fca54ecc6ff45
# Número de bytes gerados: 25
#
# Estado 391:
# R1: 1111100000111011001
# R2: 1011001010101110010001
# R3: 11010001111111011101001
#
# Keystream gerada até agora:
# Em bits: 00011110 11111001 00111001 00001000 11011011 00100010 11110101 10010011 01111101 10011011 11010001 10000001 10110010 01011110 11011001 11100101 11001001 10011111 00111111 11001010 01010100 11101100 11000110 11111111 01000101 11010
# Em bytes (hex): 1ef93908db22f5937d9bd181b25ed9e5c99f3fca54ecc6ff45
# Número de bytes gerados: 25
#
# Estado 392:
# R1: 1111100000111011001
# R2: 1101100101010111001000
# R3: 01101000111111101110100
#
# Keystream gerada até agora:
# Em bits: 00011110 11111001 00111001 00001000 11011011 00100010 11110101 10010011 01111101 10011011 11010001 10000001 10110010 01011110 11011001 11100101 11001001 10011111 00111111 11001010 01010100 11101100 11000110 11111111 01000101 110101
# Em bytes (hex): 1ef93908db22f5937d9bd181b25ed9e5c99f3fca54ecc6ff45
# Número de bytes gerados: 25
#
# Estado 393:
# R1: 1111110000011101100
# R2: 0110110010101011100100
# R3: 01101000111111101110100
#
# Keystream gerada até agora:
# Em bits: 00011110 11111001 00111001 00001000 11011011 00100010 11110101 10010011 01111101 10011011 11010001 10000001 10110010 01011110 11011001 11100101 11001001 10011111 00111111 11001010 01010100 11101100 11000110 11111111 01000101 1101011
# Em bytes (hex): 1ef93908db22f5937d9bd181b25ed9e5c99f3fca54ecc6ff45
# Número de bytes gerados: 25
#
# Estado 394:
# R1: 1111110000011101100
# R2: 0011011001010101110010
# R3: 10110100011111110111010
#
# Keystream gerada até agora:
# Em bits: 00011110 11111001 00111001 00001000 11011011 00100010 11110101 10010011 01111101 10011011 11010001 10000001 10110010 01011110 11011001 11100101 11001001 10011111 00111111 11001010 01010100 11101100 11000110 11111111 01000101 11010110
# Em bytes (hex): 1ef93908db22f5937d9bd181b25ed9e5c99f3fca54ecc6ff45d6
# Número de bytes gerados: 26
#
# Estado 395:
# R1: 0111111000001110110
# R2: 1001101100101010111001
# R3: 10110100011111110111010
#
# Keystream gerada até agora:
# Em bits: 00011110 11111001 00111001 00001000 11011011 00100010 11110101 10010011 01111101 10011011 11010001 10000001 10110010 01011110 11011001 11100101 11001001 10011111 00111111 11001010 01010100 11101100 11000110 11111111 01000101 11010110 0
# Em bytes (hex): 1ef93908db22f5937d9bd181b25ed9e5c99f3fca54ecc6ff45d6
# Número de bytes gerados: 26
#
# Estado 396:
# R1: 0111111000001110110
# R2: 1100110110010101011100
# R3: 11011010001111111011101
#
# Keystream gerada até agora:
# Em bits: 00011110 11111001 00111001 00001000 11011011 00100010 11110101 10010011 01111101 10011011 11010001 10000001 10110010 01011110 11011001 11100101 11001001 10011111 00111111 11001010 01010100 11101100 11000110 11111111 01000101 11010110 01
# Em bytes (hex): 1ef93908db22f5937d9bd181b25ed9e5c99f3fca54ecc6ff45d6
# Número de bytes gerados: 26
#
# Estado 397:
# R1: 1011111100000111011
# R2: 0110011011001010101110
# R3: 11011010001111111011101
#
# Keystream gerada até agora:
# Em bits: 00011110 11111001 00111001 00001000 11011011 00100010 11110101 10010011 01111101 10011011 11010001 10000001 10110010 01011110 11011001 11100101 11001001 10011111 00111111 11001010 01010100 11101100 11000110 11111111 01000101 11010110 011
# Em bytes (hex): 1ef93908db22f5937d9bd181b25ed9e5c99f3fca54ecc6ff45d6
# Número de bytes gerados: 26
#
# Estado 398:
# R1: 1101111110000011101
# R2: 1011001101100101010111
# R3: 11011010001111111011101
#
# Keystream gerada até agora:
# Em bits: 00011110 11111001 00111001 00001000 11011011 00100010 11110101 10010011 01111101 10011011 11010001 10000001 10110010 01011110 11011001 11100101 11001001 10011111 00111111 11001010 01010100 11101100 11000110 11111111 01000101 11010110 0110
# Em bytes (hex): 1ef93908db22f5937d9bd181b25ed9e5c99f3fca54ecc6ff45d6
# Número de bytes gerados: 26
#
# Estado 399:
# R1: 0110111111000001110
# R2: 0101100110110010101011
# R3: 01101101000111111101110
#
# Keystream gerada até agora:
# Em bits: 00011110 11111001 00111001 00001000 11011011 00100010 11110101 10010011 01111101 10011011 11010001 10000001 10110010 01011110 11011001 11100101 11001001 10011111 00111111 11001010 01010100 11101100 11000110 11111111 01000101 11010110 01101
# Em bytes (hex): 1ef93908db22f5937d9bd181b25ed9e5c99f3fca54ecc6ff45d6
# Número de bytes gerados: 26
#
# Estado 400:
# R1: 0011011111100000111
# R2: 0010110011011001010101
# R3: 01101101000111111101110
#
# Keystream gerada até agora:
# Em bits: 00011110 11111001 00111001 00001000 11011011 00100010 11110101 10010011 01111101 10011011 11010001 10000001 10110010 01011110 11011001 11100101 11001001 10011111 00111111 11001010 01010100 11101100 11000110 11111111 01000101 11010110 011011
# Em bytes (hex): 1ef93908db22f5937d9bd181b25ed9e5c99f3fca54ecc6ff45d6
# Número de bytes gerados: 26
#
# Estado 401:
# R1: 0011011111100000111
# R2: 1001011001101100101010
# R3: 10110110100011111110111
#
# Keystream gerada até agora:
# Em bits: 00011110 11111001 00111001 00001000 11011011 00100010 11110101 10010011 01111101 10011011 11010001 10000001 10110010 01011110 11011001 11100101 11001001 10011111 00111111 11001010 01010100 11101100 11000110 11111111 01000101 11010110 0110110
# Em bytes (hex): 1ef93908db22f5937d9bd181b25ed9e5c99f3fca54ecc6ff45d6
# Número de bytes gerados: 26
#
# Estado 402:
# R1: 1001101111110000011
# R2: 1100101100110110010101
# R3: 10110110100011111110111
#
# Keystream gerada até agora:
# Em bits: 00011110 11111001 00111001 00001000 11011011 00100010 11110101 10010011 01111101 10011011 11010001 10000001 10110010 01011110 11011001 11100101 11001001 10011111 00111111 11001010 01010100 11101100 11000110 11111111 01000101 11010110 01101100
# Em bytes (hex): 1ef93908db22f5937d9bd181b25ed9e5c99f3fca54ecc6ff45d66c
# Número de bytes gerados: 27
#
# Estado 403:
# R1: 0100110111111000001
# R2: 1110010110011011001010
# R3: 10110110100011111110111
#
# Keystream gerada até agora:
# Em bits: 00011110 11111001 00111001 00001000 11011011 00100010 11110101 10010011 01111101 10011011 11010001 10000001 10110010 01011110 11011001 11100101 11001001 10011111 00111111 11001010 01010100 11101100 11000110 11111111 01000101 11010110 01101100 1
# Em bytes (hex): 1ef93908db22f5937d9bd181b25ed9e5c99f3fca54ecc6ff45d66c
# Número de bytes gerados: 27
#
# Estado 404:
# R1: 0100110111111000001
# R2: 1111001011001101100101
# R3: 11011011010001111111011
#
# Keystream gerada até agora:
# Em bits: 00011110 11111001 00111001 00001000 11011011 00100010 11110101 10010011 01111101 10011011 11010001 10000001 10110010 01011110 11011001 11100101 11001001 10011111 00111111 11001010 01010100 11101100 11000110 11111111 01000101 11010110 01101100 10
# Em bytes (hex): 1ef93908db22f5937d9bd181b25ed9e5c99f3fca54ecc6ff45d66c
# Número de bytes gerados: 27
#
# Estado 405:
# R1: 0100110111111000001
# R2: 1111100101100110110010
# R3: 11101101101000111111101
#
# Keystream gerada até agora:
# Em bits: 00011110 11111001 00111001 00001000 11011011 00100010 11110101 10010011 01111101 10011011 11010001 10000001 10110010 01011110 11011001 11100101 11001001 10011111 00111111 11001010 01010100 11101100 11000110 11111111 01000101 11010110 01101100 101
# Em bytes (hex): 1ef93908db22f5937d9bd181b25ed9e5c99f3fca54ecc6ff45d66c
# Número de bytes gerados: 27
#
# Estado 406:
# R1: 1010011011111100000
# R2: 1111110010110011011001
# R3: 11110110110100011111110
#
# Keystream gerada até agora:
# Em bits: 00011110 11111001 00111001 00001000 11011011 00100010 11110101 10010011 01111101 10011011 11010001 10000001 10110010 01011110 11011001 11100101 11001001 10011111 00111111 11001010 01010100 11101100 11000110 11111111 01000101 11010110 01101100 1010
# Em bytes (hex): 1ef93908db22f5937d9bd181b25ed9e5c99f3fca54ecc6ff45d66c
# Número de bytes gerados: 27
#
# Estado 407:
# R1: 1101001101111110000
# R2: 1111111001011001101100
# R3: 11110110110100011111110
#
# Keystream gerada até agora:
# Em bits: 00011110 11111001 00111001 00001000 11011011 00100010 11110101 10010011 01111101 10011011 11010001 10000001 10110010 01011110 11011001 11100101 11001001 10011111 00111111 11001010 01010100 11101100 11000110 11111111 01000101 11010110 01101100 10101
# Em bytes (hex): 1ef93908db22f5937d9bd181b25ed9e5c99f3fca54ecc6ff45d66c
# Número de bytes gerados: 27
#
# Estado 408:
# R1: 1110100110111111000
# R2: 0111111100101100110110
# R3: 01111011011010001111111
#
# Keystream gerada até agora:
# Em bits: 00011110 11111001 00111001 00001000 11011011 00100010 11110101 10010011 01111101 10011011 11010001 10000001 10110010 01011110 11011001 11100101 11001001 10011111 00111111 11001010 01010100 11101100 11000110 11111111 01000101 11010110 01101100 101010
# Em bytes (hex): 1ef93908db22f5937d9bd181b25ed9e5c99f3fca54ecc6ff45d66c
# Número de bytes gerados: 27
#
# Estado 409:
# R1: 1111010011011111100
# R2: 1011111110010110011011
# R3: 00111101101101000111111
#
# Keystream gerada até agora:
# Em bits: 00011110 11111001 00111001 00001000 11011011 00100010 11110101 10010011 01111101 10011011 11010001 10000001 10110010 01011110 11011001 11100101 11001001 10011111 00111111 11001010 01010100 11101100 11000110 11111111 01000101 11010110 01101100 1010101
# Em bytes (hex): 1ef93908db22f5937d9bd181b25ed9e5c99f3fca54ecc6ff45d66c
# Número de bytes gerados: 27
#
# Estado 410:
# R1: 0111101001101111110
# R2: 1011111110010110011011
# R3: 00011110110110100011111
#
# Keystream gerada até agora:
# Em bits: 00011110 11111001 00111001 00001000 11011011 00100010 11110101 10010011 01111101 10011011 11010001 10000001 10110010 01011110 11011001 11100101 11001001 10011111 00111111 11001010 01010100 11101100 11000110 11111111 01000101 11010110 01101100 10101010
# Em bytes (hex): 1ef93908db22f5937d9bd181b25ed9e5c99f3fca54ecc6ff45d66caa
# Número de bytes gerados: 28
#
# Estado 411:
# R1: 1011110100110111111
# R2: 0101111111001011001101
# R3: 10001111011011010001111
#
# Keystream gerada até agora:
# Em bits: 00011110 11111001 00111001 00001000 11011011 00100010 11110101 10010011 01111101 10011011 11010001 10000001 10110010 01011110 11011001 11100101 11001001 10011111 00111111 11001010 01010100 11101100 11000110 11111111 01000101 11010110 01101100 10101010 0
# Em bytes (hex): 1ef93908db22f5937d9bd181b25ed9e5c99f3fca54ecc6ff45d66caa
# Número de bytes gerados: 28
#
# Estado 412:
# R1: 0101111010011011111
# R2: 1010111111100101100110
# R3: 10001111011011010001111
#
# Keystream gerada até agora:
# Em bits: 00011110 11111001 00111001 00001000 11011011 00100010 11110101 10010011 01111101 10011011 11010001 10000001 10110010 01011110 11011001 11100101 11001001 10011111 00111111 11001010 01010100 11101100 11000110 11111111 01000101 11010110 01101100 10101010 01
# Em bytes (hex): 1ef93908db22f5937d9bd181b25ed9e5c99f3fca54ecc6ff45d66caa
# Número de bytes gerados: 28
#
# Estado 413:
# R1: 1010111101001101111
# R2: 1101011111110010110011
# R3: 01000111101101101000111
#
# Keystream gerada até agora:
# Em bits: 00011110 11111001 00111001 00001000 11011011 00100010 11110101 10010011 01111101 10011011 11010001 10000001 10110010 01011110 11011001 11100101 11001001 10011111 00111111 11001010 01010100 11101100 11000110 11111111 01000101 11010110 01101100 10101010 010
# Em bytes (hex): 1ef93908db22f5937d9bd181b25ed9e5c99f3fca54ecc6ff45d66caa
# Número de bytes gerados: 28
#
# Estado 414:
# R1: 1010111101001101111
# R2: 0110101111111001011001
# R3: 00100011110110110100011
#
# Keystream gerada até agora:
# Em bits: 00011110 11111001 00111001 00001000 11011011 00100010 11110101 10010011 01111101 10011011 11010001 10000001 10110010 01011110 11011001 11100101 11001001 10011111 00111111 11001010 01010100 11101100 11000110 11111111 01000101 11010110 01101100 10101010 0101
# Em bytes (hex): 1ef93908db22f5937d9bd181b25ed9e5c99f3fca54ecc6ff45d66caa
# Número de bytes gerados: 28
#
# === Verificação de Burst na Keystream ===
# Verificando bursts nos primeiros 8 passos...
# Burst de 3 zeros encontrado na posição 0 da keystream.
#
# === Verificação de Repetição de Burst na Keystream ===
# Nenhuma repetição de burst detectada na keystream.
